# %% [markdown]
# # Filter Sentences for Training Data

# %%
import pandas as pd
import ast

# Specify the path to your CSV file
file_path = "parsed_sentences.csv"

# Read the CSV file into a DataFrame
data = pd.read_csv(file_path)
data.iloc[:, 1] = data.iloc[:, 1].apply(ast.literal_eval)

# Display the first few rows
print(data.head())
# Out:
#                       Sentence  \
# 0                           a!
# 1                       a a a!
# 2                       a a a.
# 3  akesi ike a li moku e moku!
# 4    akesi ike li moku e moku.
#
#                                       Parser Outputs
# 0  [s(exc(inj(expletive(interjection(a))))), s(in...
# 1  [s(exc(inj(laughing(interjection(a),interjecti...
# 2  [s(dec(inj(laughing(interjection(a),interjecti...
# 3  [s(exc(inj_to_do(subj_p((noun(akesi),adjective...
# 4  [s(dec(subj_p((noun(akesi),adjective(ike))),pr...

# %%
filtered_data = data[data["Parser Outputs"].apply(len) == 1]
filtered_data.iloc[:, 1] = filtered_data.iloc[:, 1].apply(lambda x: x[0])

# %%
filtered_data
# Out:
#                                   Sentence  \
# 2                                   a a a.
# 4                akesi ike li moku e moku.
# 5                akesi kin li moku e moku.
# 6        akesi kin, tu kin li moku e moku.
# 7     akesi kin, tu mi kin li moku e moku.
# ...                                    ...
# 2109                              wan taso
# 2122                        wile ala moku.
# 2124                            wile moku.
# 2125      wile pi jan ike li pakala e ijo.
# 2126             wile sona li mute e sona.
#
#                                          Parser Outputs
# 2     s(dec(inj(laughing(interjection(a),interjectio...
# 4     s(dec(subj_p((noun(akesi),adjective(ike))),pre...
# 5     s(dec(subj_p((noun(akesi),adjective(kin))),pre...
# 6     s(dec(subj_p((noun(akesi),adjective(kin),card(...
# 7     s(dec(subj_p((noun(akesi),adjective(kin),card(...
# ...                                                 ...
# 2109       headline(obj_i((noun(wan),adjective(taso))))
# 2122  s(dec(answer(no(verb_p(wile),adverb(ala),verb_...
# 2124     s(dec(answer(yes(verb_p(wile),verb_t(moku)))))
# 2125  s(dec(subj_p((noun(wile),noun(jan),adjective(i...
# 2126  s(dec(subj_p((noun(wile),adjective(sona))),pre...
#
# [778 rows x 2 columns]

# %%
filtered_data.to_csv("filtered_sentences.csv")

# %% [markdown]
# # Categorize Official Words List

# %%
import json

# Read JSON data from a file
with open('official_words.json', 'r') as file:
    input_json = json.load(file)

# Print each key-value pair and transform the JSON
output_json = {}
for key, value in input_json.items():
    print(f"Category: {key}, Words: {list(value.keys())}")  # Print the key-value pair
    output_json[key] = list(value.keys())  # Transform the value into a list of keys
# Out:
# Category: adjective, Words: ['akesi', 'ala', 'alasa', 'ale', 'ali', 'anpa', 'ante', 'awen', 'esun', 'ijo', 'ike', 'ilo', 'insa', 'jaki', 'jan', 'jelo', 'jo', 'kala', 'kalama', 'kama', 'kasi', 'kili', 'kin', 'kiwen', 'kon', 'kule', 'kulupu', 'kute', 'lape', 'laso', 'lawa', 'len', 'lete', 'lili', 'linja', 'lipu', 'loje', 'lon', 'luka', 'lukin', 'lupa', 'ma', 'mama', 'mani', 'meli', 'mije', 'moku', 'moli', 'monsi', 'monsuta', 'mu', 'mun', 'musi', 'mute', 'namako', 'nanpa', 'nasa', 'nasin', 'nena', 'noka', 'oko', 'olin', 'open', 'pakala', 'pali', 'palisa', 'pana', 'pilin', 'pimeja', 'pini', 'poka', 'pona', 'pu', 'sama', 'seli', 'sewi', 'sijelo', 'sike', 'sin', 'sinpin', 'sitelen', 'sona', 'soweli', 'suli', 'suno', 'supa', 'suwi', 'tan', 'taso', 'tawa', 'telo', 'tenpo', 'toki', 'tomo', 'unpa', 'uta', 'utala', 'walo', 'waso', 'wawa', 'weka', 'wile']
# Category: adverb, Words: ['ala', 'ale', 'ali', 'anpa', 'awen', 'ijo', 'ike', 'ilo', 'jaki', 'jan', 'kama', 'kili', 'kin', 'kiwen', 'kon', 'lape', 'lawa', 'lete', 'lili', 'lukin', 'mani', 'moku', 'moli', 'mu', 'musi', 'mute', 'nasa', 'noka', 'pakala', 'pali', 'pilin', 'pini', 'pona', 'sama', 'seli', 'sewi', 'sijelo', 'sike', 'sin', 'sitelen', 'suli', 'suno', 'taso', 'tawa', 'telo', 'tenpo', 'toki', 'tomo', 'unpa', 'uta', 'utala', 'wawa', 'weka', 'wile']
# Category: conjunction, Words: ['ante', 'anu', 'en', 'ike', 'kin', 'open', 'pona', 'taso']
# Category: interjection, Words: ['a', 'mu', 'o']
# Category: noun, Words: ['akesi', 'ala', 'alasa', 'ale', 'ali', 'anpa', 'ante', 'awen', 'esun', 'ijo', 'ike', 'ilo', 'insa', 'jaki', 'jan', 'jelo', 'jo', 'kala', 'kalama', 'kama', 'kasi', 'ken', 'kepeken', 'kili', 'kin', 'kipisi', 'kiwen', 'ko', 'kon', 'kule', 'kulupu', 'kute', 'lape', 'laso', 'lawa', 'len', 'lete', 'lili', 'linja', 'lipu', 'loje', 'lon', 'luka', 'lukin', 'lupa', 'ma', 'mama', 'mani', 'meli', 'mije', 'moku', 'moli', 'monsi', 'monsuta', 'mu', 'mun', 'musi', 'mute', 'namako', 'nanpa', 'nasa', 'nasin', 'nena', 'nimi', 'noka', 'oko', 'olin', 'open', 'pakala', 'pali', 'palisa', 'pan', 'pana', 'pilin', 'pimeja', 'pini', 'pipi', 'poka', 'poki', 'pona', 'pu', 'sama', 'seli', 'selo', 'sewi', 'sijelo', 'sike', 'sin', 'sinpin', 'sitelen', 'sona', 'soweli', 'suli', 'suno', 'supa', 'suwi', 'tan', 'tawa', 'telo', 'tenpo', 'toki', 'tomo', 'tu', 'unpa', 'uta', 'utala', 'walo', 'wan', 'waso', 'wawa', 'weka', 'wile']
# Category: numeral, Words: ['ala', 'wan', 'tu', 'luka', 'ten', 'mute', 'ale']
# Category: preposition, Words: ['kepeken', 'lon', 'poka', 'sama', 'tan', 'tawa']
# Category: pronoun, Words: ['mi', 'sina', 'ona', 'ni']
# Category: pronoun_interrogative, Words: ['seme']
# Category: separator, Words: ['e', 'la', 'li', 'o', 'pi']
# Category: punctuation, Words: ['.', '!', '?', ':', ',', '"', "'"]
# Category: intransitive_verb, Words: ['anpa', 'awen', 'ike', 'kalama', 'kama', 'kasi', 'ken', 'kepeken', 'kon', 'lape', 'lon', 'lukin', 'moli', 'mu', 'musi', 'pakala', 'pali', 'pilin', 'pu', 'sewi', 'sona', 'tan', 'tawa', 'toki', 'unpa']
# Category: transitive_verb, Words: ['alasa', 'anpa', 'ante', 'awen', 'esun', 'ijo', 'ike', 'ilo', 'jaki', 'jan', 'jelo', 'jo', 'kalama', 'kama', 'kasi', 'ken', 'kipisi', 'kiwen', 'ko', 'kon', 'kule', 'kulupu', 'kute', 'lape', 'lawa', 'len', 'lete', 'lili', 'lon', 'lukin', 'lupa', 'mama', 'moku', 'moli', 'mu', 'musi', 'mute', 'namako', 'nanpa', 'nasa', 'nimi', 'olin', 'open', 'pakala', 'pali', 'palisa', 'pan', 'pana', 'pilin', 'pimeja', 'pini', 'poki', 'pona', 'pu', 'sama', 'seli', 'selo', 'sewi', 'sike', 'sin', 'sijelo', 'sitelen', 'sona', 'suli', 'suno', 'supa', 'suwi', 'tawa', 'telo', 'toki', 'tomo', 'tu', 'unpa', 'uta', 'utala', 'walo', 'wan', 'wawa', 'weka', 'wile']
# Category: verb_pre, Words: ['kama', 'ken', 'kepeken', 'lukin', 'open', 'pini', 'pu', 'sona', 'wile']

# %%
import pprint
pprint.pprint(output_json)
# Out:
# {'adjective': ['akesi',
#                'ala',
#                'alasa',
#                'ale',
#                'ali',
#                'anpa',
#                'ante',
#                'awen',
#                'esun',
#                'ijo',
#                'ike',
#                'ilo',
#                'insa',
#                'jaki',
#                'jan',
#                'jelo',
#                'jo',
#                'kala',
#                'kalama',
#                'kama',
#                'kasi',
#                'kili',
#                'kin',
#                'kiwen',
#                'kon',
#                'kule',
#                'kulupu',
#                'kute',
#                'lape',
#                'laso',
#                'lawa',
#                'len',
#                'lete',
#                'lili',
#                'linja',
#                'lipu',
#                'loje',
#                'lon',
#                'luka',
#                'lukin',
#                'lupa',
#                'ma',
#                'mama',
#                'mani',
#                'meli',
#                'mije',
#                'moku',
#                'moli',
#                'monsi',
#                'monsuta',
#                'mu',
#                'mun',
#                'musi',
#                'mute',
#                'namako',
#                'nanpa',
#                'nasa',
#                'nasin',
#                'nena',
#                'noka',
#                'oko',
#                'olin',
#                'open',
#                'pakala',
#                'pali',
#                'palisa',
#                'pana',
#                'pilin',
#                'pimeja',
#                'pini',
#                'poka',
#                'pona',
#                'pu',
#                'sama',
#                'seli',
#                'sewi',
#                'sijelo',
#                'sike',
#                'sin',
#                'sinpin',
#                'sitelen',
#                'sona',
#                'soweli',
#                'suli',
#                'suno',
#                'supa',
#                'suwi',
#                'tan',
#                'taso',
#                'tawa',
#                'telo',
#                'tenpo',
#                'toki',
#                'tomo',
#                'unpa',
#                'uta',
#                'utala',
#                'walo',
#                'waso',
#                'wawa',
#                'weka',
#                'wile'],
#  'adverb': ['ala',
#             'ale',
#             'ali',
#             'anpa',
#             'awen',
#             'ijo',
#             'ike',
#             'ilo',
#             'jaki',
#             'jan',
#             'kama',
#             'kili',
#             'kin',
#             'kiwen',
#             'kon',
#             'lape',
#             'lawa',
#             'lete',
#             'lili',
#             'lukin',
#             'mani',
#             'moku',
#             'moli',
#             'mu',
#             'musi',
#             'mute',
#             'nasa',
#             'noka',
#             'pakala',
#             'pali',
#             'pilin',
#             'pini',
#             'pona',
#             'sama',
#             'seli',
#             'sewi',
#             'sijelo',
#             'sike',
#             'sin',
#             'sitelen',
#             'suli',
#             'suno',
#             'taso',
#             'tawa',
#             'telo',
#             'tenpo',
#             'toki',
#             'tomo',
#             'unpa',
#             'uta',
#             'utala',
#             'wawa',
#             'weka',
#             'wile'],
#  'conjunction': ['ante', 'anu', 'en', 'ike', 'kin', 'open', 'pona', 'taso'],
#  'interjection': ['a', 'mu', 'o'],
#  'intransitive_verb': ['anpa',
#                        'awen',
#                        'ike',
#                        'kalama',
#                        'kama',
#                        'kasi',
#                        'ken',
#                        'kepeken',
#                        'kon',
#                        'lape',
#                        'lon',
#                        'lukin',
#                        'moli',
#                        'mu',
#                        'musi',
#                        'pakala',
#                        'pali',
#                        'pilin',
#                        'pu',
#                        'sewi',
#                        'sona',
#                        'tan',
#                        'tawa',
#                        'toki',
#                        'unpa'],
#  'noun': ['akesi',
#           'ala',
#           'alasa',
#           'ale',
#           'ali',
#           'anpa',
#           'ante',
#           'awen',
#           'esun',
#           'ijo',
#           'ike',
#           'ilo',
#           'insa',
#           'jaki',
#           'jan',
#           'jelo',
#           'jo',
#           'kala',
#           'kalama',
#           'kama',
#           'kasi',
#           'ken',
#           'kepeken',
#           'kili',
#           'kin',
#           'kipisi',
#           'kiwen',
#           'ko',
#           'kon',
#           'kule',
#           'kulupu',
#           'kute',
#           'lape',
#           'laso',
#           'lawa',
#           'len',
#           'lete',
#           'lili',
#           'linja',
#           'lipu',
#           'loje',
#           'lon',
#           'luka',
#           'lukin',
#           'lupa',
#           'ma',
#           'mama',
#           'mani',
#           'meli',
#           'mije',
#           'moku',
#           'moli',
#           'monsi',
#           'monsuta',
#           'mu',
#           'mun',
#           'musi',
#           'mute',
#           'namako',
#           'nanpa',
#           'nasa',
#           'nasin',
#           'nena',
#           'nimi',
#           'noka',
#           'oko',
#           'olin',
#           'open',
#           'pakala',
#           'pali',
#           'palisa',
#           'pan',
#           'pana',
#           'pilin',
#           'pimeja',
#           'pini',
#           'pipi',
#           'poka',
#           'poki',
#           'pona',
#           'pu',
#           'sama',
#           'seli',
#           'selo',
#           'sewi',
#           'sijelo',
#           'sike',
#           'sin',
#           'sinpin',
#           'sitelen',
#           'sona',
#           'soweli',
#           'suli',
#           'suno',
#           'supa',
#           'suwi',
#           'tan',
#           'tawa',
#           'telo',
#           'tenpo',
#           'toki',
#           'tomo',
#           'tu',
#           'unpa',
#           'uta',
#           'utala',
#           'walo',
#           'wan',
#           'waso',
#           'wawa',
#           'weka',
#           'wile'],
#  'numeral': ['ala', 'wan', 'tu', 'luka', 'ten', 'mute', 'ale'],
#  'preposition': ['kepeken', 'lon', 'poka', 'sama', 'tan', 'tawa'],
#  'pronoun': ['mi', 'sina', 'ona', 'ni'],
#  'pronoun_interrogative': ['seme'],
#  'punctuation': ['.', '!', '?', ':', ',', '"', "'"],
#  'separator': ['e', 'la', 'li', 'o', 'pi'],
#  'transitive_verb': ['alasa',
#                      'anpa',
#                      'ante',
#                      'awen',
#                      'esun',
#                      'ijo',
#                      'ike',
#                      'ilo',
#                      'jaki',
#                      'jan',
#                      'jelo',
#                      'jo',
#                      'kalama',
#                      'kama',
#                      'kasi',
#                      'ken',
#                      'kipisi',
#                      'kiwen',
#                      'ko',
#                      'kon',
#                      'kule',
#                      'kulupu',
#                      'kute',
#                      'lape',
#                      'lawa',
#                      'len',
#                      'lete',
#                      'lili',
#                      'lon',
#                      'lukin',
#                      'lupa',
#                      'mama',
#                      'moku',
#                      'moli',
#                      'mu',
#                      'musi',
#                      'mute',
#                      'namako',
#                      'nanpa',
#                      'nasa',
#                      'nimi',
#                      'olin',
#                      'open',
#                      'pakala',
#                      'pali',
#                      'palisa',
#                      'pan',
#                      'pana',
#                      'pilin',
#                      'pimeja',
#                      'pini',
#                      'poki',
#                      'pona',
#                      'pu',
#                      'sama',
#                      'seli',
#                      'selo',
#                      'sewi',
#                      'sike',
#                      'sin',
#                      'sijelo',
#                      'sitelen',
#                      'sona',
#                      'suli',
#                      'suno',
#                      'supa',
#                      'suwi',
#                      'tawa',
#                      'telo',
#                      'toki',
#                      'tomo',
#                      'tu',
#                      'unpa',
#                      'uta',
#                      'utala',
#                      'walo',
#                      'wan',
#                      'wawa',
#                      'weka',
#                      'wile'],
#  'verb_pre': ['kama',
#               'ken',
#               'kepeken',
#               'lukin',
#               'open',
#               'pini',
#               'pu',
#               'sona',
#               'wile']}

# %% [markdown]
# # Prompt Generation

# %%
i = 0
for _, row in filtered_data.iterrows():
    print("Give ONLY the CoNNL-U output for the following sentence-parser output pair")
    print(f"Sentence : {row['Sentence']}")
    print(f"Parser Output : {row['Parser Outputs']}")
    print()
# Out:
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : a a a.
# Parser Output : s(dec(inj(laughing(interjection(a),interjection(a),interjection(a)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi ike li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(ike))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi kin, tu kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(kin),card(numeral(tu)),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi kin, tu mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(kin),card(numeral(tu)),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi li pakala e tomo e soweli pi mute seme?
# Parser Output : s(int(how_many_object(subj_p(noun(akesi)),(pred_p(verb_t(pakala),obj_d(noun(tomo))),obj_d(noun(soweli),noun(mute),pronoun_interrogative(seme))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi li pana e telo moli.
# Parser Output : s(dec(subj_p(noun(akesi)),pred_p(verb_t(pana),obj_d((noun(telo),adjective(moli))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi Lolo
# Parser Output : headline(obj_i((noun(akesi),unofficial_thing(unknown(Lolo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi Lonlon
# Parser Output : headline(obj_i((noun(akesi),unofficial_thing(unknown(Lonlon)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi mi, tu li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),pronoun(mi),card(numeral(tu)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi mi tu taso li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),pronoun(mi),card(numeral(tu)),adjective(taso))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pi jan Ana, en jan Lope li moku e moku.
# Parser Output : s(dec(subj_p(((noun(akesi),noun(jan),unofficial_female_name(known_female_name(Ana))),conj(en),noun(jan),unofficial_male_name(known_male_name(Lope)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pi jan Lope en jan Patala pona ni
# Parser Output : headline(obj_i((noun(akesi),(noun(jan),unofficial_male_name(known_male_name(Lope))),conj(en),noun(jan),unofficial_person_name(unknown(Patala)),adjective(pona),pronoun(ni))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pi mije Mawen li utala e ijo ni.
# Parser Output : s(dec(subj_p((noun(akesi),noun(mije),unofficial_male_name(known_male_name(Mawen)))),pred_p(verb_t(utala),obj_d((noun(ijo),pronoun(ni))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona kin, tu kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(pona),adjective(kin)),card(numeral(tu)),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona kin, tu mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(pona),adjective(kin)),card(numeral(tu)),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona, tu kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(pona),card(numeral(tu)),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona tu li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(pona),card(numeral(tu)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona, tu mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(pona),card(numeral(tu)),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi pona tu mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(pona),card(numeral(tu)),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli ike li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(suli),adjective(ike))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli ike mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(ike)),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo ike li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(suli),adjective(jelo),adjective(ike))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(jelo)),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo mi, tu wan li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(jelo)),pronoun(mi),card((numeral(tu),numeral(wan))))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo, tu wan mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(jelo)),card((numeral(tu),numeral(wan))),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo, tu wan mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(jelo)),card((numeral(tu),numeral(wan))),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli jelo, tu wan mi ni li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),(adjective(suli),adjective(jelo)),card((numeral(tu),numeral(wan))),pronoun(mi),pronoun(ni))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(suli))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli mi kin li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(suli),pronoun(mi),adjective(kin))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : akesi suli mi li moku e moku.
# Parser Output : s(dec(subj_p((noun(akesi),adjective(suli),pronoun(mi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ale li jo e tenpo.
# Parser Output : s(dec(subj_p(noun(ale)),pred_p(verb_t(jo),obj_d(noun(tenpo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ale li jo e tenpo ona.
# Parser Output : s(dec(subj_p(noun(ale)),pred_p(verb_t(jo),obj_d((noun(tenpo),pronoun(ona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : anu mi moku e moku!
# Parser Output : s(conj(anu),exc(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : anu mi moku e moku.
# Parser Output : s(conj(anu),dec(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : anu mi moku e moku a!
# Parser Output : s(conj(anu),exc(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : anu mi moku e moku a.
# Parser Output : s(conj(anu),exc(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : anu mi wile e ni: jan li ken pana e sona pi ma tomo ni, tawa mi.
# Parser Output : s(conj(anu),dec(subj_p(pronoun(mi)),pred_p(verb_t(wile),obj_d(pronoun(ni))),subj_p(noun(jan)),pred_p((verb_p(ken),verb_t(pana)),obj_d((noun(sona),noun(ma),adjective(tomo),pronoun(ni))),obj_p(preposition(tawa),pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en moku
# Parser Output : headline(conj(en),obj_i(noun(moku)))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en moku a
# Parser Output : headline(conj(en),obj_i(noun(moku)),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en o moku e moku!
# Parser Output : s(conj(en),imp(com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en o moku e telo a.
# Parser Output : s(conj(en),imp(com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(telo))))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en seme?
# Parser Output : s(conj(en),int(pardon(pronoun_interrogative(seme))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en seme a?
# Parser Output : s(conj(en),int(pardon(pronoun_interrogative(seme))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en sina o a
# Parser Output : headline(conj(en),obj_i(pronoun(sina)),(interjection(o),interjection(a)))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : en sina pona ala pona e tawa?
# Parser Output : s(conj(en),int(yes_no(subj_p(pronoun(sina)),pred_p(verb_t(pona),adverb(ala),verb_t(pona),obj_d(noun(tawa))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo jelo seme li pakala e ona?
# Parser Output : s(int(which_subject(subj_p((noun(ijo),adjective(jelo),pronoun_interrogative(seme))),pred_p(verb_t(pakala),obj_d(pronoun(ona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo Lapalapala
# Parser Output : headline(obj_i((noun(ijo),unofficial_thing(unknown(Lapalapala)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo li lukin e mi.
# Parser Output : s(dec(subj_p(noun(ijo)),pred_p(verb_t(lukin),obj_d(pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo li moku e mi.
# Parser Output : s(dec(subj_p(noun(ijo)),pred_p(verb_t(moku),obj_d(pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo li pali e ijo.
# Parser Output : s(dec(subj_p(noun(ijo)),pred_p(verb_t(pali),obj_d(noun(ijo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo MIRC
# Parser Output : headline(obj_i((noun(ijo),unofficial_thing(known_thing(MIRC)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo sin ni li kasi pi nanpa wan!
# Parser Output : s(exc(subj_p((noun(ijo),adjective(sin),pronoun(ni))),pred_p(verb_i(be),(noun(kasi),noun(nanpa),card(numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ijo wan li wawa e ijo tu la ijo tu li wawa e ijo wan.
# Parser Output : s(dec(cond_p(subj_p((noun(ijo),card(numeral(wan)))),pred_p(verb_t(wawa),obj_d((noun(ijo),card(numeral(tu)))))),subj_p((noun(ijo),card(numeral(tu)))),pred_p(verb_t(wawa),obj_d((noun(ijo),card(numeral(wan)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ilo Alikali
# Parser Output : headline(obj_i((noun(ilo),unofficial_thing(unknown(Alikali)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ilo li lon poki.
# Parser Output : s(dec(subj_p(noun(ilo)),pred_p(verb_i(lon),obj_i(noun(poki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ilo moku li lili ala lili?
# Parser Output : s(int(yes_no(subj_p((noun(ilo),adjective(moku))),pred_p(verb_t(lili),adverb(ala),verb_t(lili)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ilo moku li toki wawa ala e jan pali pi ilo moku!
# Parser Output : s(exc(subj_p((noun(ilo),adjective(moku))),pred_p((verb_t(toki),adverb(wawa),adverb(ala)),obj_d(((noun(jan),adjective(pali)),noun(ilo),adjective(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : ilo sitelen pi toki sewi li wawa e ni.
# Parser Output : s(dec(subj_p(((noun(ilo),adjective(sitelen)),noun(toki),adjective(sewi))),pred_p(verb_t(wawa),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ala
# Parser Output : headline(obj_i((noun(jan),card(numeral(ala)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale ale luka wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(ale),numeral(luka),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale ale mute mute luka tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(ale),(numeral(mute),numeral(mute)),numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale luka tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(luka),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale mute
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(mute))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale mute luka tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(mute),numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale mute mute luka tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),(numeral(mute),numeral(mute)),numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, ale tu tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(ale),numeral(tu),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ante li lukin e soweli li toki e ni.
# Parser Output : s(dec(subj_p((noun(jan),adjective(ante))),(pred_p(verb_t(lukin),obj_d(noun(soweli))),pred_p(pred_p(verb_t(toki),obj_d(pronoun(ni)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ante li toki pakala e ona.
# Parser Output : s(dec(subj_p((noun(jan),adjective(ante))),pred_p((verb_t(toki),adverb(pakala)),obj_d(pronoun(ona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Elopa
# Parser Output : headline(obj_i((noun(jan),unofficial_resident(known_continent(Elopa)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan God li toki e toki.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(famous_person(God)))),pred_p(verb_t(toki),obj_d(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ike Devil wawa li ike e ni.
# Parser Output : s(dec(subj_p((noun(jan),adjective(ike),unofficial_person_name(famous_person(Devil)),adjective(wawa))),pred_p(verb_t(ike),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ike Kin li pakala e tenpo pona Kolisu!
# Parser Output : s(exc(subj_p((noun(jan),adjective(ike),unofficial_person_name(unknown(Kin)))),pred_p(verb_t(pakala),obj_d((noun(tenpo),adjective(pona),unofficial_thing(unknown(Kolisu)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ike li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),adjective(ike))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ike ni li jo e len nasa.
# Parser Output : s(dec(subj_p((noun(jan),adjective(ike),pronoun(ni))),pred_p(verb_t(jo),obj_d((noun(len),adjective(nasa))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Isa li toki e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Isa)))),pred_p(verb_t(toki),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Jon li pali e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Jon)))),pred_p(verb_t(pali),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Kitopokolonpo
# Parser Output : headline(obj_i((noun(jan),unofficial_person_name(unknown(Kitopokolonpo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Kolonpo li jo e tomo tawa Ninja e tomo tawa Pinta e tomo tawa Santamalija.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Kolonpo)))),pred_p(verb_t(jo),(obj_d((noun(tomo),adjective(tawa),unofficial_thing(unknown(Ninja)))),obj_d((noun(tomo),adjective(tawa),unofficial_thing(unknown(Pinta)))),obj_d((noun(tomo),adjective(tawa),unofficial_thing(unknown(Santamalija))))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Kulisa li pali e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Kulisa)))),pred_p(verb_t(pali),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lalalalalala li toki e toki.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Lalalalalala)))),pred_p(verb_t(toki),obj_d(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lapalapala
# Parser Output : headline(obj_i((noun(jan),unofficial_person_name(unknown(Lapalapala)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa
# Parser Output : headline(obj_i((noun(jan),adjective(lawa))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa lete
# Parser Output : headline(obj_i((noun(jan),adjective(lawa),adjective(lete))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa lete li kama e lete suli wawa.
# Parser Output : s(dec(subj_p((noun(jan),adjective(lawa),adjective(lete))),pred_p(verb_t(kama),obj_d((noun(lete),adjective(suli),adjective(wawa))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa lete li lete e nimi pi lon uta ona.
# Parser Output : s(dec(subj_p((noun(jan),adjective(lawa),adjective(lete))),pred_p(verb_t(lete),obj_d((noun(nimi),noun(lon),adjective(uta),pronoun(ona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa li moku e telo jaki.
# Parser Output : s(dec(subj_p((noun(jan),adjective(lawa))),pred_p(verb_t(moku),obj_d((noun(telo),adjective(jaki))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa li wile sona e ni tan jan Isa.
# Parser Output : s(dec(subj_p((noun(jan),adjective(lawa))),pred_p((verb_p(wile),verb_t(sona)),obj_d(pronoun(ni)),obj_p(preposition(tan),(noun(jan),unofficial_person_name(unknown(Isa)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan lawa Talana li toki e ni.
# Parser Output : s(dec(subj_p((noun(jan),adjective(lawa),unofficial_person_name(unknown(Talana)))),pred_p(verb_t(toki),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, lili lili lili
# Parser Output : headline(obj_i((noun(jan),card((adjective(lili),adjective(lili),adjective(lili))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li lukin e ma.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p(verb_t(lukin),obj_d(noun(ma)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li moku e moku.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li moli e waso.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p(verb_t(moli),obj_d(noun(waso)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li pali e seme?
# Parser Output : s(int(what_d_object(subj_p(noun(jan)),pred_p(verb_t(pali),obj_d(pronoun_interrogative(seme))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li pilin e olin.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p(verb_t(pilin),obj_d(noun(olin)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lisa anu jan Lope li moku e moku?
# Parser Output : s(int(decision_subject(subj_p((noun(jan),unofficial_female_name(known_female_name(Lisa))),conj(anu),(noun(jan),unofficial_male_name(known_male_name(Lope)))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lisa anu sina li moku e moku?
# Parser Output : s(int(decision_subject(subj_p((noun(jan),unofficial_female_name(known_female_name(Lisa))),conj(anu),pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lisa li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_female_name(known_female_name(Lisa)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lisa o, toki.
# Parser Output : s(dec(voc(voca_p((noun(jan),unofficial_female_name(known_female_name(Lisa)))),salu_p(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li toki e ni.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p(verb_t(toki),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan li wile jo e ma.
# Parser Output : s(dec(subj_p(noun(jan)),pred_p((verb_p(wile),verb_t(jo)),obj_d(noun(ma)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lo
# Parser Output : headline(obj_i((noun(jan),unofficial_person_name(unknown(Lo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lomonopo
# Parser Output : headline(obj_i((noun(jan),unofficial_person_name(unknown(Lomonopo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope li moku e moku pona.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_male_name(known_male_name(Lope)))),pred_p(verb_t(moku),obj_d((noun(moku),adjective(pona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope o, sina moku e moku a!
# Parser Output : s(exc(voc(voca_p((noun(jan),unofficial_male_name(known_male_name(Lope)))),subj_p(pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku))))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope o, sina olin ala olin e mi?
# Parser Output : s(int(voc(voca_p((noun(jan),unofficial_male_name(known_male_name(Lope)))),yes_no(subj_p(pronoun(sina)),pred_p(verb_t(olin),adverb(ala),verb_t(olin),obj_d(pronoun(mi)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope o, toki a!
# Parser Output : s(exc(voc(voca_p((noun(jan),unofficial_male_name(known_male_name(Lope)))),salu_p(noun(toki)))),interjection(a))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope pi ma suli Elopa li ' lon ma Tosi.
# Parser Output : s(dec(subj_p(((noun(jan),unofficial_male_name(known_male_name(Lope))),noun(ma),adjective(suli),unofficial_continent(known_continent(Elopa)))),pred_p(verb_i(be),(noun(lon),adjective(ma),unofficial_thing(unknown(Tosi))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Lope pi ma tomo Pelin pona li kama sona e toki pona li pali e ilo pi toki pona.
# Parser Output : s(dec(subj_p(((noun(jan),unofficial_male_name(known_male_name(Lope))),noun(ma),adjective(tomo),unofficial_city(known_city(Pelin)),adjective(pona))),(pred_p((verb_p(kama),verb_t(sona)),obj_d((noun(toki),adjective(pona)))),pred_p(pred_p(verb_t(pali),obj_d((noun(ilo),noun(toki),adjective(pona))))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka
# Parser Output : headline(obj_i((noun(jan),card(numeral(luka)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka luka
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(luka))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka luka wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(luka),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka tu tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(tu),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, luka wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(luka),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mali li pali e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_resident(known_country(Mali)))),pred_p(verb_t(pali),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ma ni li jan seme?
# Parser Output : s(int(what_is_object(subj_p((noun(jan),adjective(ma),pronoun(ni))),pred_p(verb_i(be),(noun(jan),pronoun_interrogative(seme))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mata li pali e kalama musi ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Mata)))),pred_p(verb_t(pali),obj_d((noun(kalama),adjective(musi),pronoun(ni))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mawen o, sina wile ala wile moku?
# Parser Output : s(int(voc(voca_p((noun(jan),unofficial_male_name(known_male_name(Mawen)))),yes_no(subj_p(pronoun(sina)),pred_p(verb_p(wile),adverb(ala),verb_p(wile),verb_t(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mawija li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_famous_woman(known_famous_woman(Mawija)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mawijo li jo e meli olin.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Mawijo)))),pred_p(verb_t(jo),obj_d((noun(meli),adjective(olin))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mawi li jan pi wile sona.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Mawi)))),pred_p(verb_i(be),(noun(jan),noun(wile),adjective(sona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mawi li toki e ni: mi jan Mawi pi jan Talana.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Mawi)))),pred_p(verb_t(toki),obj_d(pronoun(ni))),subj_p(pronoun(mi)),pred_p(verb_i(be),((noun(jan),unofficial_person_name(unknown(Mawi))),noun(jan),unofficial_person_name(unknown(Talana))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Mesiko
# Parser Output : headline(obj_i((noun(jan),unofficial_resident(known_country(Mesiko)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, mute lili
# Parser Output : headline(obj_i((noun(jan),card((adjective(mute),adjective(lili))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, mute mute luka tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(mute),numeral(mute),numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, mute mute mute
# Parser Output : headline(obj_i((noun(jan),card((adjective(mute),adjective(mute),adjective(mute))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, mute mute mute li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),card((adjective(mute),adjective(mute),adjective(mute))))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, mute tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(mute),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa ala
# Parser Output : headline(obj_i((noun(jan),ord(adjective(nanpa),numeral(ala)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa ale mute luka tu wan
# Parser Output : headline(obj_i((noun(jan),ord(adjective(nanpa),(numeral(ale),numeral(mute),numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa luka tu wan
# Parser Output : headline(obj_i((noun(jan),ord(adjective(nanpa),(numeral(luka),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa mute mute mute li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),ord(adjective(nanpa),(adjective(mute),adjective(mute),adjective(mute))))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan nanpa, nanpa tu tu
# Parser Output : headline(obj_i((noun(jan),adjective(nanpa),ord(adjective(nanpa),(numeral(tu),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan nanpa, tu li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),adjective(nanpa),card(numeral(tu)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa tu tu wan
# Parser Output : headline(obj_i((noun(jan),ord(adjective(nanpa),(numeral(tu),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, nanpa tu wan li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),ord(adjective(nanpa),(numeral(tu),numeral(wan))))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Nikita li toki e toki.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_male_name(known_male_name(Nikita)))),pred_p(verb_t(toki),obj_d(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ni li toki e ni, kepeken toki Inli.
# Parser Output : s(dec(subj_p((noun(jan),pronoun(ni))),pred_p(verb_t(toki),obj_d(pronoun(ni)),obj_p(preposition(kepeken),(noun(toki),unofficial_language(known_language(Inli)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ni li toki e ni, kepeken toki Inli pona.
# Parser Output : s(dec(subj_p((noun(jan),pronoun(ni))),pred_p(verb_t(toki),obj_d(pronoun(ni)),obj_p(preposition(kepeken),(noun(toki),unofficial_language(known_language(Inli)),adjective(pona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan ni li toki e ni, kepeken toki luka Inli pona.
# Parser Output : s(dec(subj_p((noun(jan),pronoun(ni))),pred_p(verb_t(toki),obj_d(pronoun(ni)),obj_p(preposition(kepeken),(noun(toki),adjective(luka),unofficial_sign_language(known_language(Inli)),adjective(pona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan o pona e tomo!
# Parser Output : s(imp(com(subj_p(noun(jan)),pred_p(verb_t(pona),obj_d(noun(tomo))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Osaka
# Parser Output : headline(obj_i((noun(jan),unofficial_resident(known_city(Osaka)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Ote li pali e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Ote)))),pred_p(verb_t(pali),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Pepe
# Parser Output : headline(obj_i((noun(jan),unofficial_male_name(known_male_name(Pepe)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi jan suli li moku e moku pona.
# Parser Output : s(dec(subj_p((noun(jan),noun(jan),adjective(suli))),pred_p(verb_t(moku),obj_d((noun(moku),adjective(pona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Pije li pali e ni.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Pije)))),pred_p(verb_t(pali),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi kulupu Neje, en jan pi ma suli Apika li pona e ilo nanpa.
# Parser Output : s(dec(subj_p(((noun(jan),noun(kulupu),unofficial_community(known_community(Neje))),conj(en),noun(jan),noun(ma),adjective(suli),unofficial_continent(known_continent(Apika)))),pred_p(verb_t(pona),obj_d((noun(ilo),adjective(nanpa))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi kulupu Neje li pona e ilo.
# Parser Output : s(dec(subj_p((noun(jan),noun(kulupu),unofficial_community(known_community(Neje)))),pred_p(verb_t(pona),obj_d(noun(ilo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi ma suli Elopa pona li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(ma),adjective(suli),unofficial_continent(known_continent(Elopa)),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi ma Sumi lete ni li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(ma),unofficial_country(known_country(Sumi)),adjective(lete),pronoun(ni))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi ma Sumi li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(ma),unofficial_country(known_country(Sumi)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi ma tomo Pelin pona li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(ma),adjective(tomo),unofficial_city(known_city(Pelin)),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi nasin pona Patapali sewi li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(nasin),adjective(pona),unofficial_ideology(known_ideology(Patapali)),adjective(sewi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi nasin sewi Patapali li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),noun(nasin),adjective(sewi),unofficial_ideology(known_ideology(Patapali)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi nasin sewi Patapali li musi e jan ni.
# Parser Output : s(dec(subj_p((noun(jan),noun(nasin),adjective(sewi),unofficial_ideology(known_ideology(Patapali)))),pred_p(verb_t(musi),obj_d((noun(jan),pronoun(ni))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pi ona pona li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),pronoun(ona),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona li moku e soweli.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(soweli)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona Lisa ni li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona),unofficial_female_name(known_female_name(Lisa)),pronoun(ni))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona Mawija ni li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona),unofficial_famous_woman(known_famous_woman(Mawija)),pronoun(ni))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona Mesiko ni li toki e toki.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona),unofficial_resident(known_country(Mesiko)),pronoun(ni))),pred_p(verb_t(toki),obj_d(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona Nikita suli ni li toki e toki.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona),unofficial_male_name(known_male_name(Nikita)),adjective(suli),pronoun(ni))),pred_p(verb_t(toki),obj_d(noun(toki)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi jan suli li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),noun(jan),adjective(suli))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi meli en mije li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),noun(meli),conj(en),noun(mije))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi meli en ona li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),noun(meli),conj(en),pronoun(ona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi meli en ona pona li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),noun(meli),conj(en),pronoun(ona),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi ona en mije li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),pronoun(ona),conj(en),noun(mije))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi ona en mije suwi li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),pronoun(ona),conj(en),noun(mije),adjective(suwi))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi ona en sina li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),pronoun(ona),conj(en),pronoun(sina))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi ona en sina pona li moku e moku.
# Parser Output : s(dec(subj_p(((noun(jan),adjective(pona)),pronoun(ona),conj(en),pronoun(sina),adjective(pona))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona pi ona pona, en sina li moku e moku.
# Parser Output : s(dec(subj_p((((noun(jan),adjective(pona)),pronoun(ona),adjective(pona)),conj(en),pronoun(sina))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona Santa ni li pana e pona.
# Parser Output : s(dec(subj_p((noun(jan),adjective(pona),unofficial_famous_man(famous_man(Santa)),pronoun(ni))),pred_p(verb_t(pana),obj_d(noun(pona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona seme li moku e moku?
# Parser Output : s(int(who(subj_p((noun(jan),adjective(pona),pronoun_interrogative(seme))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona seme pi mama sina li moku e moku?
# Parser Output : s(int(who(subj_p((noun(jan),adjective(pona),pronoun_interrogative(seme),noun(mama),pronoun(sina))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan pona seme pi mama sina pi mama ona li moku e moku?
# Parser Output : s(int(who(subj_p((noun(jan),adjective(pona),pronoun_interrogative(seme),(noun(mama),pronoun(sina)),noun(mama),pronoun(ona))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Santa li pana e pona.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_famous_man(famous_man(Santa)))),pred_p(verb_t(pana),obj_d(noun(pona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan seme li moku e moku?
# Parser Output : s(int(who(subj_p((noun(jan),pronoun_interrogative(seme))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan seme li pali e supa ni?
# Parser Output : s(int(who(subj_p((noun(jan),pronoun_interrogative(seme))),pred_p(verb_t(pali),obj_d((noun(supa),pronoun(ni)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan seme pi mama sina li moku e moku?
# Parser Output : s(int(who(subj_p((noun(jan),pronoun_interrogative(seme),noun(mama),pronoun(sina))),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Sesi o moku e kili ni!
# Parser Output : s(imp(com(subj_p((noun(jan),unofficial_female_name(known_female_name(Sesi)))),pred_p(verb_t(moku),obj_d((noun(kili),pronoun(ni)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan sewi li olin e sina.
# Parser Output : s(dec(subj_p((noun(jan),adjective(sewi))),pred_p(verb_t(olin),obj_d(pronoun(sina)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan sona li toki e ni.
# Parser Output : s(dec(subj_p((noun(jan),adjective(sona))),pred_p(verb_t(toki),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Sulu li utala e jan ike.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Sulu)))),pred_p(verb_t(utala),obj_d((noun(jan),adjective(ike))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Susan
# Parser Output : headline(obj_i((noun(jan),unofficial_female_name(known_female_name(Susan)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Susan anu jan Lisa li moku e suwi?
# Parser Output : s(int(decision_subject(subj_p((noun(jan),unofficial_female_name(known_female_name(Susan))),conj(anu),(noun(jan),unofficial_female_name(known_female_name(Lisa)))),pred_p(verb_t(moku),obj_d(noun(suwi))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan Toni li sona e ni: mi olin e ona.
# Parser Output : s(dec(subj_p((noun(jan),unofficial_person_name(unknown(Toni)))),pred_p(verb_t(sona),obj_d(pronoun(ni))),subj_p(pronoun(mi)),pred_p(verb_t(olin),obj_d(pronoun(ona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu
# Parser Output : headline(obj_i((noun(jan),card(numeral(tu)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu li moku e moku.
# Parser Output : s(dec(subj_p((noun(jan),card(numeral(tu)))),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(tu),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu tu tu
# Parser Output : headline(obj_i((noun(jan),card((numeral(tu),numeral(tu),numeral(tu))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu tu tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(tu),numeral(tu),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(tu),numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan, tu wan
# Parser Output : headline(obj_i((noun(jan),card((numeral(tu),numeral(wan))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : jan utala li pakala e ijo ike.
# Parser Output : s(dec(subj_p((noun(jan),adjective(utala))),pred_p(verb_t(pakala),obj_d((noun(ijo),adjective(ike))))))
#
# ...
# Parser Output : s(dec(cond_p((noun(tan),pronoun(ni))),subj_p(pronoun(sina)),pred_p((verb_p(kama),verb_t(jo)),obj_d((noun(kalama),noun(mani),pronoun(ona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tan seme la soweli wawa pimeja li moku e ona?
# Parser Output : s(int(why_la(cond_p(noun(tan),pronoun_interrogative(seme)),subj_p((noun(soweli),adjective(wawa),adjective(pimeja))),pred_p(verb_t(moku),obj_d(pronoun(ona))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso mi jo ala e moku.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(mi)),pred_p((verb_t(jo),adverb(ala)),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso mi moku e moku.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso, mi moku e moku.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso mi pilin e ni: mi toki e lon.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(mi)),pred_p(verb_t(pilin),obj_d(pronoun(ni))),subj_p(pronoun(mi)),pred_p(verb_t(toki),obj_d(noun(lon)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso o kama jo e poki suli mani kin.
# Parser Output : s(conj(taso),imp(com(subj_p(interjection(o)),pred_p((verb_p(kama),verb_t(jo)),obj_d((noun(poki),adjective(suli),adjective(mani),adjective(kin)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso ona li awen e wan.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(ona)),pred_p(verb_t(awen),obj_d(noun(wan)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso ona li pana e len pi noka mije li len e lawa ona!
# Parser Output : s(conj(taso),exc(subj_p(pronoun(ona)),(pred_p(verb_t(pana),obj_d((noun(len),noun(noka),adjective(mije)))),pred_p(pred_p(verb_t(len),obj_d((noun(lawa),pronoun(ona))))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso seli li seli wawa e telo.
# Parser Output : s(conj(taso),dec(subj_p(noun(seli)),pred_p((verb_t(seli),adverb(wawa)),obj_d(noun(telo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso sina ken kin kama sona e ijo sin.
# Parser Output : s(conj(taso),dec(subj_p(pronoun(sina)),pred_p((verb_p(ken),(adverb(kin),adverb(kama)),verb_t(sona)),obj_d((noun(ijo),adjective(sin))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : taso tenpo pimeja ni la meli suli li unpa kin e mije ante pi nasin sewi!
# Parser Output : s(conj(taso),exc(cond_p((noun(tenpo),adjective(pimeja),pronoun(ni))),subj_p((noun(meli),adjective(suli))),pred_p((verb_t(unpa),adverb(kin)),obj_d(((noun(mije),adjective(ante)),noun(nasin),adjective(sewi))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tawa pona!
# Parser Output : s(exc(salut(salu_p(noun(tawa),adjective(pona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tawa pona.
# Parser Output : s(dec(salut(salu_p(noun(tawa),adjective(pona)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : telo li wawa e mi.
# Parser Output : s(dec(subj_p(noun(telo)),pred_p(verb_t(wawa),obj_d(pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo ali la mi pali e ike.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(ali))),subj_p(pronoun(mi)),pred_p(verb_t(pali),obj_d(noun(ike)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la ken la mi moku e moku.
# Parser Output : s(dec((cond_p((noun(tenpo),adjective(kama))),cond_p(noun(ken))),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la, ken, la mi moku e moku.
# Parser Output : s(dec((cond_p((noun(tenpo),adjective(kama))),cond_p(noun(ken))),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la mi moku e moku la ken.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(kama))),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku))),cond_p(noun(ken))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la mi wile e ni: ken la mi moku e moku.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(kama))),subj_p(pronoun(mi)),pred_p(verb_t(wile),obj_d(pronoun(ni))),cond_p(noun(ken)),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la mi wile e ni: ken la o moku e moku!
# Parser Output : s(imp(cond_p((noun(tenpo),adjective(kama))),subj_p(pronoun(mi)),pred_p(verb_t(wile),obj_d(pronoun(ni))),cond_p(noun(ken)),com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la mi wile e ni: mi moku e moku.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(kama))),subj_p(pronoun(mi)),pred_p(verb_t(wile),obj_d(pronoun(ni))),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la o moku e moku!
# Parser Output : s(imp(cond_p((noun(tenpo),adjective(kama))),com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la o moku e moku la ken!
# Parser Output : s(imp(cond_p((noun(tenpo),adjective(kama))),com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(moku)))),cond_p(noun(ken))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la o wile e ni: o moku e moku!
# Parser Output : s(imp(cond_p((noun(tenpo),adjective(kama))),com(subj_p(interjection(o)),pred_p(verb_t(wile),obj_d(pronoun(ni)))),com(subj_p(interjection(o)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la o wile e ni: sina moku e moku!
# Parser Output : s(imp(cond_p((noun(tenpo),adjective(kama))),com(subj_p(interjection(o)),pred_p(verb_t(wile),obj_d(pronoun(ni)))),subj_p(pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la seme: ken la mi moku e moku?
# Parser Output : s(int(cond_p((noun(tenpo),adjective(kama))),pardon(pronoun_interrogative(seme)),cond_p(noun(ken)),subj_p(pronoun(mi)),pred_p(verb_t(moku),obj_d(noun(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la seme: ken la seme?
# Parser Output : s(int(cond_p((noun(tenpo),adjective(kama))),pardon(pronoun_interrogative(seme)),cond_p(noun(ken)),pardon(pronoun_interrogative(seme))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la seme la ken?
# Parser Output : s(int(cond_p((noun(tenpo),adjective(kama))),pardon(pronoun_interrogative(seme)),cond_p(noun(ken))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo kama la sina wile ala wile moku?
# Parser Output : s(int(cond_p((noun(tenpo),adjective(kama))),yes_no(subj_p(pronoun(sina)),pred_p(verb_p(wile),adverb(ala),verb_p(wile),verb_t(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo ni la sina awen ala awen seli?
# Parser Output : s(int(cond_p((noun(tenpo),pronoun(ni))),yes_no(subj_p(pronoun(sina)),pred_p(verb_i(awen),adverb(ala),verb_i(awen),obj_i(noun(seli))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pi ma ali
# Parser Output : headline(obj_i((noun(tenpo),noun(ma),adjective(ali))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pimeja pini la mi lukin e sitelen tawa X-Files.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(pimeja),adjective(pini))),subj_p(pronoun(mi)),pred_p(verb_t(lukin),obj_d((noun(sitelen),adjective(tawa),unofficial_movie(known_movie(X-Files)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pimeja wan la meli ante li lukin e weka pi mije ni.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(pimeja),card(numeral(wan)))),subj_p((noun(meli),adjective(ante))),pred_p(verb_t(lukin),obj_d((noun(weka),noun(mije),pronoun(ni))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pi mute seme la sina sike e suno?
# Parser Output : s(int(how_many_la(cond_p(noun(tenpo),noun(mute),pronoun_interrogative(seme)),subj_p(pronoun(sina)),pred_p(verb_t(sike),obj_d(noun(suno))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pona seme la sina moku e moku?
# Parser Output : s(int(when_la(cond_p(noun(tenpo),adjective(pona),pronoun_interrogative(seme)),subj_p(pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo pona sina seme la sina moku e moku?
# Parser Output : s(int(when_la(cond_p(noun(tenpo),(adjective(pona),pronoun(sina)),pronoun_interrogative(seme)),subj_p(pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo seme la sina moku e moku?
# Parser Output : s(int(when_la(cond_p(noun(tenpo),pronoun_interrogative(seme)),subj_p(pronoun(sina)),pred_p(verb_t(moku),obj_d(noun(moku))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo suli pini la jan li jo e soweli tawa pi nena kute suli.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(suli),adjective(pini))),subj_p(noun(jan)),pred_p(verb_t(jo),obj_d(((noun(soweli),adjective(tawa)),noun(nena),adjective(kute),adjective(suli))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo suno pini la jan Sili li pona e tomo, li telo e len.
# Parser Output : s(dec(cond_p((noun(tenpo),adjective(suno),adjective(pini))),subj_p((noun(jan),unofficial_person_name(unknown(Sili)))),(pred_p(verb_t(pona),obj_d(noun(tomo))),pred_p(pred_p(verb_t(telo),obj_d(noun(len)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo tu la ona li wile e ni: meli suli li lukin e unpa.
# Parser Output : s(dec(cond_p((noun(tenpo),card(numeral(tu)))),subj_p(pronoun(ona)),pred_p(verb_t(wile),obj_d(pronoun(ni))),subj_p((noun(meli),adjective(suli))),pred_p(verb_t(lukin),obj_d(noun(unpa)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo tu tu la mi sike e suno.
# Parser Output : s(dec(cond_p((noun(tenpo),card((numeral(tu),numeral(tu))))),subj_p(pronoun(mi)),pred_p(verb_t(sike),obj_d(noun(suno)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo wan la ona li lukin e mije wan li olin e ona.
# Parser Output : s(dec(cond_p((noun(tenpo),card(numeral(wan)))),subj_p(pronoun(ona)),(pred_p(verb_t(lukin),obj_d((noun(mije),card(numeral(wan))))),pred_p(pred_p(verb_t(olin),obj_d(pronoun(ona)))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tenpo wan la sina olin ala olin?
# Parser Output : s(int(cond_p((noun(tenpo),card(numeral(wan)))),yes_no(subj_p(pronoun(sina)),pred_p(verb_t(olin),adverb(ala),verb_t(olin)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki Epelanto
# Parser Output : headline(obj_i((noun(toki),unofficial_language(known_language(Epelanto)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki Inli pi ma Inli li ' pona pi pona ni, tawa jan ali.
# Parser Output : s(dec(subj_p(((noun(toki),unofficial_language(known_language(Inli))),noun(ma),unofficial_country(known_country(Inli)))),pred_p(verb_i(be),(noun(pona),noun(pona),pronoun(ni)),obj_p(preposition(tawa),(noun(jan),adjective(ali))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki Lapalapa
# Parser Output : headline(obj_i((noun(toki),unofficial_language(unknown(Lapalapa)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki luka Inli
# Parser Output : headline(obj_i((noun(toki),adjective(luka),unofficial_sign_language(known_language(Inli)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki luka Lapalapala
# Parser Output : headline(obj_i((noun(toki),adjective(luka),unofficial_sign_language(unknown(Lapalapala)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : toki utala pi pimeja soweli
# Parser Output : headline(obj_i(((noun(toki),adjective(utala)),noun(pimeja),adjective(soweli))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo li jo e ilo toki.
# Parser Output : s(dec(subj_p(noun(tomo)),pred_p(verb_t(jo),obj_d((noun(ilo),adjective(toki))))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo pi ona kin
# Parser Output : headline(obj_i((noun(tomo),pronoun(ona),adjective(kin))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo sona li jo e lipu.
# Parser Output : s(dec(subj_p((noun(tomo),adjective(sona))),pred_p(verb_t(jo),obj_d(noun(lipu)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo tawa pi jan pona li tawa e mi.
# Parser Output : s(dec(subj_p(((noun(tomo),adjective(tawa)),noun(jan),adjective(pona))),pred_p(verb_t(tawa),obj_d(pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo tawa pi jan wan li tawa e mi.
# Parser Output : s(dec(subj_p(((noun(tomo),adjective(tawa)),noun(jan),card(numeral(wan)))),pred_p(verb_t(tawa),obj_d(pronoun(mi)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo tawa, wan kin li tawa e ni.
# Parser Output : s(dec(subj_p((noun(tomo),adjective(tawa),card(numeral(wan)),adjective(kin))),pred_p(verb_t(tawa),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : tomo tawa, wan taso li tawa e ni.
# Parser Output : s(dec(subj_p((noun(tomo),adjective(tawa),card(numeral(wan)),adjective(taso))),pred_p(verb_t(tawa),obj_d(pronoun(ni)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : wan taso
# Parser Output : headline(obj_i((noun(wan),adjective(taso))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : wile ala moku.
# Parser Output : s(dec(answer(no(verb_p(wile),adverb(ala),verb_t(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : wile moku.
# Parser Output : s(dec(answer(yes(verb_p(wile),verb_t(moku)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : wile pi jan ike li pakala e ijo.
# Parser Output : s(dec(subj_p((noun(wile),noun(jan),adjective(ike))),pred_p(verb_t(pakala),obj_d(noun(ijo)))))
#
# Give ONLY the CoNNL-U output for the following sentence-parser output pair
# Sentence : wile sona li mute e sona.
# Parser Output : s(dec(subj_p((noun(wile),adjective(sona))),pred_p(verb_t(mute),obj_d(noun(sona)))))
